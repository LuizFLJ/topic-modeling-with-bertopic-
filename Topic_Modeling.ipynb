# %% [markdown]
# <a href="https://colab.research.google.com/github/LuizFLJ/topic-modeling-with-bertopic-/blob/main/Topic_Modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install bertopic
# !pip install git+https://github.com/MaartenGr/BERTopic.git@refs/pull/668/merge
# !pip install tweepy

# %% [markdown]
# ## Data

# %%
from sklearn.datasets import fetch_20newsgroups
docs = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'))['data']

# %% [markdown]
# # **Topic Modeling**

# %%
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer

sentence_model = SentenceTransformer("distiluse-base-multilingual-cased-v1", device='cpu')
model = BERTopic(embedding_model=sentence_model, language='multilingual', calculate_probabilities=True, verbose=True)
topics, probs = model.fit_transform(docs)
# Out:
# Downloading:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/114 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.58M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.38k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/556 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/539M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/452 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/341 [00:00<?, ?B/s]
# Batches:   0%|          | 0/589 [00:00<?, ?it/s]
# 2022-09-04 21:58:32,502 - BERTopic - Transformed documents to Embeddings
# 2022-09-04 21:59:17,378 - BERTopic - Reduced dimensionality
# ...

# %%
freq = model.get_topic_info()
freq.head(20)
# Out:
#     Topic  Count                                   Name
# 0      -1   5877                       -1_the_to_and_of
# 1       0   1778                   0_game_team_he_games
# 2       1   1338                    1_god_jesus_that_of
# 3       2    729              2_space_launch_nasa_orbit
# 4       3    665          3_key_clipper_chip_encryption
# 5       4    543     4_unsubscribe_melittin_critus_ites
# 6       5    485             5_israel_israeli_jews_arab
# 7       6    455                    6_jpeg_db_gif_image
# 8       7    371                  7_bike_dod_bikes_ride
# 9       8    268                8_gun_guns_firearms_you
# 10      9    246                9_drive_scsi_ide_drives
# 11     10    230         10_monitor_monitors_vga_screen
# 12     11    216            11_card_drivers_ati_diamond
# 13     12    185               12_car_ford_cars_mustang
# 14     13    174            13_printer_print_hp_deskjet
# 15     14    172                  14_lib_x11r5_usr_echo
# ...

# %%
model.get_topic(0)
# Out:
# [('game', 0.012412195574314314),
#  ('team', 0.010665444858387316),
#  ('he', 0.009846203240964423),
#  ('games', 0.008155943412601736),
#  ('season', 0.007421476900564798),
#  ('hockey', 0.007213029290152737),
#  ('year', 0.007068392237849297),
#  ('play', 0.006855216990519141),
#  ('players', 0.0067158281605113465),
#  ('was', 0.006239447541666286)]

# %% [markdown]
# ## Visualise Topics

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Visualise Topic Probabilities
#
# It means how confident the model is about each topic

# %%
model.visualize_distribution(probs[200], min_probability=0.015)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Visualize Terms

# %%
model.visualize_barchart(top_n_topics=5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
